# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("khanfashee/nih-chest-x-ray-14-224x224-resized")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /Users/JChuang/.cache/kagglehub/datasets/khanfashee/nih-chest-x-ray-14-224x224-resized/versions/3

# %% [markdown]
# # Project 4: Instructions
#
# 1. Train a CNN for multi-label, multi-class classification of chest x-ray images with associated radiographic findings.
# 2. Implement three or more methods for data augmentation and/or other methods for handling class imbalance.
# 3. Compare performance on Average PA (area under precision-recall curve), AUROC, F1-score.
# 4. Optionally, students can analyze model calibration using calibration error metrics.
